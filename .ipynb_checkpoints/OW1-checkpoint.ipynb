# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter('ignore', DeprecationWarning)
# %matplotlib inline 

df = pd.read_csv('responses.csv', sep=",")

# %%
df
# Out:
#       Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0       5.0                       3.0    2.0   1.0      2.0              2.0
# 1       4.0                       4.0    2.0   1.0      1.0              1.0
# 2       5.0                       5.0    2.0   2.0      3.0              4.0
# 3       5.0                       3.0    2.0   1.0      1.0              1.0
# 4       5.0                       3.0    4.0   3.0      2.0              4.0
# 5       5.0                       3.0    2.0   3.0      2.0              3.0
# 6       5.0                       5.0    5.0   3.0      1.0              2.0
# 7       5.0                       3.0    3.0   2.0      1.0              2.0
# 8       5.0                       3.0    3.0   1.0      1.0              2.0
# 9       5.0                       3.0    2.0   5.0      2.0              2.0
# 10      5.0                       3.0    3.0   2.0      1.0              2.0
# ...

# %%
# df.dropna(how='any')
df.isnull().any()
# Out:
# Music                          True
# Slow songs or fast songs       True
# Dance                          True
# Folk                           True
# Country                        True
# Classical music                True
# Musical                        True
# Pop                            True
# Rock                           True
# Metal or Hardrock              True
# Punk                           True
# Hiphop, Rap                    True
# Reggae, Ska                    True
# Swing, Jazz                    True
# Rock n roll                    True
# Alternative                    True
# Latino                         True
# Techno, Trance                 True
# Opera                          True
# Movies                         True
# Horror                         True
# Thriller                       True
# Comedy                         True
# Romantic                       True
# Sci-fi                         True
# War                            True
# ...

# %%
df.Music.isnull().sum()
# Out:
# 3

# %%
import math

music_mean_value = math.floor(df.Music.mean())
music_mean_value
# Out:
# 4

# %%
df.Music.fillna(value = music_mean_value)
# Out:
# 0       5.0
# 1       4.0
# 2       5.0
# 3       5.0
# 4       5.0
# 5       5.0
# 6       5.0
# 7       5.0
# 8       5.0
# 9       5.0
# 10      5.0
# 11      5.0
# 12      5.0
# 13      5.0
# 14      5.0
# 15      1.0
# 16      5.0
# 17      5.0
# 18      5.0
# 19      5.0
# 20      5.0
# 21      5.0
# 22      5.0
# 23      5.0
# 24      5.0
# 25      5.0
# 26      5.0
# 27      4.0
# 28      5.0
# 29      5.0
#        ...
# 980     5.0
# 981     5.0
# 982     5.0
# 983     5.0
# 984     5.0
# 985     5.0
# 986     4.0
# 987     4.0
# 988     5.0
# 989     5.0
# 990     5.0
# 991     5.0
# 992     4.0
# 993     5.0
# 994     5.0
# 995     5.0
# 996     5.0
# 997     5.0
# 998     5.0
# 999     5.0
# 1000    5.0
# 1001    5.0
# 1002    5.0
# 1003    4.0
# 1004    5.0
# 1005    5.0
# 1006    4.0
# 1007    4.0
# 1008    5.0
# 1009    5.0
# Name: Music, dtype: float64

# %%
df.isnull().sum()
# Out:
# Music                          3
# Slow songs or fast songs       2
# Dance                          4
# Folk                           5
# Country                        5
# Classical music                7
# Musical                        2
# Pop                            3
# Rock                           6
# Metal or Hardrock              3
# Punk                           8
# Hiphop, Rap                    4
# Reggae, Ska                    7
# Swing, Jazz                    6
# Rock n roll                    7
# Alternative                    7
# Latino                         8
# Techno, Trance                 7
# Opera                          1
# Movies                         6
# Horror                         2
# Thriller                       1
# Comedy                         3
# Romantic                       3
# Sci-fi                         2
# War                            2
# Fantasy/Fairy tales            3
# Animated                       3
# ...

# %%
df_imputed = df.fillna(df.median()) # note that to do this all values must be numeric
df_imputed.isnull().sum()
# Out:
# Music                         0
# Slow songs or fast songs      0
# Dance                         0
# Folk                          0
# Country                       0
# Classical music               0
# Musical                       0
# Pop                           0
# Rock                          0
# Metal or Hardrock             0
# Punk                          0
# Hiphop, Rap                   0
# Reggae, Ska                   0
# Swing, Jazz                   0
# Rock n roll                   0
# Alternative                   0
# Latino                        0
# Techno, Trance                0
# Opera                         0
# Movies                        0
# Horror                        0
# Thriller                      0
# Comedy                        0
# Romantic                      0
# Sci-fi                        0
# War                           0
# Fantasy/Fairy tales           0
# Animated                      0
# Documentary                   0
# ...

# %%
df_imputed.columns[df_imputed.isnull().any()].tolist()
# Out:
# ['Smoking',
#  'Alcohol',
#  'Punctuality',
#  'Lying',
#  'Gender',
#  'Left - right handed',
#  'Education',
#  'Only child',
#  'Village - town',
#  'House - block of flats']

# %%
df.Alcohol
# Out:
# 0          drink a lot
# 1          drink a lot
# 2          drink a lot
# 3          drink a lot
# 4       social drinker
# 5                never
# 6       social drinker
# 7          drink a lot
# 8       social drinker
# 9          drink a lot
# 10      social drinker
# 11               never
# 12      social drinker
# 13      social drinker
# 14      social drinker
# 15      social drinker
# 16         drink a lot
# 17      social drinker
# 18      social drinker
# 19         drink a lot
# 20               never
# 21      social drinker
# 22      social drinker
# 23      social drinker
# 24               never
# 25      social drinker
# 26      social drinker
# 27      social drinker
# 28      social drinker
# 29      social drinker
#              ...
# 980        drink a lot
# 981     social drinker
# 982        drink a lot
# 983     social drinker
# 984        drink a lot
# 985     social drinker
# 986     social drinker
# 987        drink a lot
# 988        drink a lot
# ...
